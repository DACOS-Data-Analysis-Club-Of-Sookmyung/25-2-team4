# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import json
from collections import defaultdict

BASE = "/content/drive/MyDrive/dacos-project"

def load_jsonl(path):
    data = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            data.append(json.loads(line))
    return data

# 1) 프로젝트 데이터 전부 로드
projects = load_jsonl(f"{BASE}/project_textified.jsonl")

# 2) project_id → 프로젝트 정보 매핑 딕셔너리
project_map = {p["project_id"]: p for p in projects}

# %%
user_id = "u00001"   # 나중에 U00002, U00003으로 바꿔가면서 쓰면 됨
BASE = "/content/drive/MyDrive/dacos-project"

# %%
import json

# CBF 결과 로드
with open(f"{BASE}/cbf_candidates_{user_id}.json", "r", encoding="utf-8") as f:
    cbf = json.load(f)

# CF 결과 로드
with open(f"{BASE}/cf_candidates_{user_id}.json", "r", encoding="utf-8") as f:
    cf = json.load(f)

print("CBF 개수:", len(cbf))
print("CF 개수:", len(cf))
# Out:
# CBF 개수: 100
# CF 개수: 48
# 샘플: {'project_id': 'p_1465', 'cbf_score': 0.496427059173584, 'details': {'text': 0.5767896175384521, 'skill': 0.8857040405273438, 'role': 0, 'field': 0}}

# %%
import os, json
import numpy as np
from datetime import datetime, date

# =========================
# 설정
# =========================
BASE = "/content/drive/MyDrive/dacos-project"
PROJECT_FILE = os.path.join(BASE, "project_textified.jsonl")

ALPHA = 0.4
BETA  = 0.6
TOP_K = 100


# =========================
# 유틸: min-max 정규화
# =========================
def minmax_norm(arr: np.ndarray) -> np.ndarray:
    arr = arr.astype(np.float32)
    mn, mx = float(arr.min()), float(arr.max())
    if mx - mn < 1e-9:
        return np.zeros_like(arr, dtype=np.float32)
    return (arr - mn) / (mx - mn + 1e-9)


# =========================
# 유틸: 후보 JSON 로드
# =========================
def load_candidates_dict(path: str, score_key: str) -> dict:
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return {d["project_id"]: float(d[score_key]) for d in data}


# =========================
# 유틸: 프로젝트 jsonl 로드
# =========================
def load_projects_index(project_path: str) -> dict:
    idx = {}
    with open(project_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            obj = json.loads(line)
            pid = obj.get("project_id")
            if pid:
                idx[pid] = obj
    return idx


# =========================
# 유틸: 마감 여부 체크
# =========================
def is_expired(deadline_str: str) -> bool:
    if not deadline_str:
        return False
    try:
        d = datetime.strptime(deadline_str, "%Y-%m-%d").date()
        return d < date.today()
    except:
        return False


# =========================
# 하이브리드 추천 메인 함수
# =========================
def hybrid_topk_excluding_expired(user_id: str, alpha=ALPHA, beta=BETA, top_k=TOP_K):
    uid = user_id.lower()

    cbf_path = os.path.join(BASE, f"cbf_candidates_{uid}.json")
    cf_path  = os.path.join(BASE, f"cf_candidates_{uid}.json")

    # 파일 체크
    if not os.path.exists(cbf_path):
        raise FileNotFoundError(f"CBF 파일 없음: {cbf_path}")
    if not os.path.exists(cf_path):
        raise FileNotFoundError(f"CF 파일 없음: {cf_path}")
    if not os.path.exists(PROJECT_FILE):
        raise FileNotFoundError(f"프로젝트 파일 없음: {PROJECT_FILE}")

    # 로드
    cbf_dict = load_candidates_dict(cbf_path, "cbf_score")
    cf_dict  = load_candidates_dict(cf_path,  "cf_score")
    projects_idx = load_projects_index(PROJECT_FILE)

    # 후보 통합
    project_ids = list(set(cbf_dict.keys()) | set(cf_dict.keys()))

    # 점수 배열
    cbf_scores = np.array([cbf_dict.get(pid, 0.0) for pid in project_ids], dtype=np.float32)
    cf_scores  = np.array([cf_dict.get(pid, 0.0)  for pid in project_ids], dtype=np.float32)

    # 정규화
    cbf_norm = minmax_norm(cbf_scores)
    cf_norm  = minmax_norm(cf_scores)

    # 가중합
    final = alpha * cbf_norm + beta * cf_norm

    # 결과 구성
    results = []
    for pid, c_raw, f_raw, c_n, f_n, fs in zip(project_ids, cbf_scores, cf_scores, cbf_norm, cf_norm, final):
        proj = projects_idx.get(pid, {})
        deadline = proj.get("deadline")

        results.append({
            "project_id": pid,
            "final_score": float(fs),
            "cbf_norm": float(c_n),
            "cf_norm": float(f_n),
            "cbf_score": float(c_raw),
            "cf_score": float(f_raw),
            "deadline": deadline,
            "p_text": proj.get("p_text"),
            "p_skill": proj.get("p_skill"),
            "p_role": proj.get("p_role"),
            "p_field": proj.get("p_field"),
        })

    # 정렬
    results.sort(key=lambda x: x["final_score"], reverse=True)

    # 마감 제거
    before = len(results)
    results = [r for r in results if not is_expired(r.get("deadline"))]
    removed = before - len(results)

    # Top-K
    topk = results[:top_k]
    return topk


    # 출력
    print(f"\n==== {user_id} Hybrid Top {top_k} (alpha={alpha}, beta={beta}) ====")
    print(f"(참고) 마감 제거: {removed}개 제거 / 전체 후보: {before}개\n")

    for i, r in enumerate(topk, start=1):
        print(f"{i:3d}. {r['project_id']} | final={r['final_score']:.4f} | deadline={r['deadline']}")
        if r.get("p_text"):
            print(f"     - {r['p_text'][:120]}")

    return topk

# %%
hybrid_topk_excluding_expired(user_id)
# Out:
# [{'project_id': 'p_0159',
#   'final_score': 0.7714098691940308,
#   'cbf_norm': 0.5399057865142822,
#   'cf_norm': 0.925745964050293,
#   'cbf_score': 0.26802384853363037,
#   'cf_score': 0.8492965698242188,
#   'deadline': '2026-03-18',
#   'p_text': '대화형 AI 챗봇 개발. 사용자의 질문에 적절히 대답하는 대화형 AI 챗봇을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, 프롬프트 엔지니어링'},
#  {'project_id': 'p_1803',
#   'final_score': 0.6670196056365967,
#   'cbf_norm': 0.6441590785980225,
#   'cf_norm': 0.6822599768638611,
#   'cbf_score': 0.3197779953479767,
#   'cf_score': 0.6259179711341858,
#   'deadline': '2026-03-14',
#   'p_text': '강화학습 기반 추천 시스템 개발. 사용자의 행동 데이터를 분석하여 개인화된 추천 결과를 제공하는 시스템을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git, PostgreSQL, Kafka',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 강화학습, MLOps'},
#  {'project_id': 'p_2926',
#   'final_score': 0.6000000238418579,
#   'cbf_norm': 0.0,
#   'cf_norm': 1.0,
#   'cbf_score': 0.0,
#   'cf_score': 0.9174185991287231,
#   'deadline': '2026-03-27',
#   'p_text': '강화학습을 활용한 거래 알고리즘 개발. 금융 시장에서 강화학습 기법을 적용하여 최적의 거래 전략을 분석하고 개발합니다.',
#   'p_skill': 'required skills: Python, SQL, Django, Docker, AWS, Git, Redis, Kafka',
#   'p_role': 'required roles: 백엔드, 데브옵스',
#   'p_field': 'project fields: 강화학습, 데이터 엔지니어링, 최적화'},
#  {'project_id': 'p_1465',
#   'final_score': 0.4000000059604645,
#   'cbf_norm': 1.0,
#   'cf_norm': 0.0,
#   'cbf_score': 0.496427059173584,
#   'cf_score': 0.0,
#   'deadline': '2026-03-23',
#   'p_text': 'AI 기반 추천 시스템 개발. 사용자의 행동 데이터를 분석하여 맞춤형 상품을 추천하는 AI 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, MySQL, Docker, AWS',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, 프라이버시/보안'},
#  {'project_id': 'p_0058',
#   'final_score': 0.3901742696762085,
#   'cbf_norm': 0.9754356741905212,
#   'cf_norm': 0.0,
#   'cbf_score': 0.48423266410827637,
#   'cf_score': 0.0,
#   'deadline': '2026-03-12',
#   'p_text': 'AI 기반 대화형 개인 비서 개발. 사용자의 요청에 맞춰 정보를 제공하고 작업을 처리하는 대화형 AI 비서를 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, 인프라 모니터링'},
#  {'project_id': 'p_1510',
#   'final_score': 0.3838023543357849,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.6396705508232117,
#   'cbf_score': 0.0,
#   'cf_score': 0.5868456363677979,
#   'deadline': '2026-02-13',
#   'p_text': '추천시스템을 위한 데이터 파이프라인 구축. 대량의 사용자 데이터를 처리하여 개인화된 추천을 제공하는 시스템을 구축합니다.',
#   'p_skill': 'required skills: Python, SQL, Django, Kafka, Docker, AWS, Git',
#   'p_role': 'required roles: 데브옵스, 백엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, MLOps'},
#  {'project_id': 'p_0197',
#   'final_score': 0.35092324018478394,
#   'cbf_norm': 0.8773080706596375,
#   'cf_norm': 0.0,
#   'cbf_score': 0.4355194568634033,
#   'cf_score': 0.0,
#   'deadline': '2026-01-12',
#   'p_text': '지능형 에이전트를 활용한 고객 지원 시스템. 고객 문의에 대해 자동으로 응답하는 지능형 에이전트 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git, Linux',
#   'p_role': 'required roles: 풀스택',
#   'p_field': 'project fields: 대화형 AI, 지능형 에이전트, 프라이버시/보안'},
#  {'project_id': 'p_1316',
#   'final_score': 0.34848591685295105,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.5808098316192627,
#   'cbf_score': 0.0,
#   'cf_score': 0.5328457355499268,
#   'deadline': '2026-03-23',
#   'p_text': 'AI 기반 추천시스템 개발. 사용자 맞춤형 콘텐츠 추천을 위한 AI 모델을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Django, AWS, Docker, PostgreSQL, Redis, Git, Kafka',
#   'p_role': 'required roles: 백엔드, 풀스택',
#   'p_field': 'project fields: 추천시스템, MLOps, 데이터 엔지니어링'},
#  {'project_id': 'p_0145',
#   'final_score': 0.34830009937286377,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.5805001258850098,
#   'cbf_score': 0.0,
#   'cf_score': 0.5325616002082825,
#   'deadline': '2026-01-23',
#   'p_text': 'AI 기반 추천 시스템 개발 프로젝트. 사용자의 선호도를 분석하여 개인화된 추천 결과를 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, AWS, Docker, Kubernetes, Redis, Git',
#   'p_role': 'required roles: 풀스택, 데브옵스',
#   'p_field': 'project fields: 추천시스템, MLOps, 클라우드 인프라'},
#  {'project_id': 'p_0102',
#   'final_score': 0.3415107727050781,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.5691846013069153,
#   'cbf_score': 0.0,
#   'cf_score': 0.5221805572509766,
#   'deadline': '2026-01-21',
#   'p_text': '대화형 AI 기반 고객 지원 시스템 구축. 고객의 문의에 실시간으로 답변하는 대화형 AI 시스템을 개발하여 서비스 품질을 향상시킵니다.',
#   'p_skill': 'required skills: Python, Django, React, PostgreSQL, Docker, AWS',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, 프라이버시/보안'},
#  {'project_id': 'p_0089',
#   'final_score': 0.3289607763290405,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.5482679605484009,
#   'cbf_score': 0.0,
#   'cf_score': 0.5029911994934082,
#   'deadline': '2026-03-30',
#   'p_text': '강화학습 기반 개인화 추천 시스템 개발. 사용자의 행동 데이터를 분석하여 개인 맞춤형 추천을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, PostgreSQL, Docker, AWS, Redis, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 강화학습, 데이터 엔지니어링'},
#  {'project_id': 'p_1947',
#   'final_score': 0.32592445611953735,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.5432074069976807,
#   'cbf_score': 0.0,
#   'cf_score': 0.49834856390953064,
#   'deadline': '2026-02-19',
#   'p_text': '강화학습 기반 추천 시스템 개발. 사용자의 행동 데이터를 기반으로 최적의 추천을 제공하기 위한 강화학습 알고리즘을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Django, Docker, AWS, PostgreSQL, Redis, Git, Kubernetes',
#   'p_role': 'required roles: 백엔드, 데브옵스',
#   'p_field': 'project fields: 추천시스템, 강화학습, AI 윤리'},
#  {'project_id': 'p_2981',
#   'final_score': 0.3130953311920166,
#   'cbf_norm': 0.7827383279800415,
#   'cf_norm': 0.0,
#   'cbf_score': 0.38857248425483704,
#   'cf_score': 0.0,
#   'deadline': '2026-02-21',
#   'p_text': 'AI 기반 멀티모달 추천 시스템 개발. 사용자의 다양한 데이터를 기반으로 맞춤형 추천을 제공하는 AI 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, GraphQL, Redis, Next.js',
#   'p_role': 'required roles: 풀스택',
#   'p_field': 'project fields: 추천시스템, 멀티모달, AI 윤리'},
#  {'project_id': 'p_0715',
#   'final_score': 0.29151222109794617,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.4858537018299103,
#   'cbf_score': 0.0,
#   'cf_score': 0.4457312226295471,
#   'deadline': '2026-02-05',
#   'p_text': 'AI 기반 멀티모달 추천 시스템 개발. 사용자의 행동 데이터를 분석하여 개인 맞춤형 추천 제공을 목적으로 하는 프로젝트입니다.',
#   'p_skill': 'required skills: Python, Django, React, PostgreSQL, AWS, Docker, Kubernetes, Git',
#   'p_role': 'required roles: 풀스택, 데브옵스',
#   'p_field': 'project fields: 추천시스템, 멀티모달, 데이터 엔지니어링'},
#  {'project_id': 'p_2067',
#   'final_score': 0.2853577136993408,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.475596159696579,
#   'cbf_score': 0.0,
#   'cf_score': 0.4363207519054413,
#   'deadline': '2026-03-02',
#   'p_text': '고급 자연어 처리 기반 챗봇 개발. 자연어 처리 기술을 활용하여 사용자와의 대화를 이해하고 응답 처리하는 고급 챗봇 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, PostgreSQL, Git, Jenkins',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 자연어 처리, AI 윤리, 대화형 AI'},
#  {'project_id': 'p_0983',
#   'final_score': 0.2846547067165375,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.47442448139190674,
#   'cbf_score': 0.0,
#   'cf_score': 0.4352458417415619,
#   'deadline': '2026-02-11',
#   'p_text': '딥러닝 기반 추천 시스템 개발. 추천 시스템의 정확도 향상을 위해 딥러닝 알고리즘을 적용하고, 데이터 전처리를 수행합니다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, Docker, AWS, TensorFlow, SQL, FastAPI',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, MLOps, 데이터 엔지니어링'},
#  {'project_id': 'p_2644',
#   'final_score': 0.2821078598499298,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.4701797664165497,
#   'cbf_score': 0.0,
#   'cf_score': 0.4313516616821289,
#   'deadline': '2026-03-10',
#   'p_text': '강화학습 기반 추천 시스템 구축. 사용자의 행동 데이터를 분석하여 효과적인 추천을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, SQL, AWS, Docker, Kubernetes, Git, React',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 강화학습, MLOps'},
#  {'project_id': 'p_0514',
#   'final_score': 0.2788957953453064,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.4648262858390808,
#   'cbf_score': 0.0,
#   'cf_score': 0.4264402687549591,
#   'deadline': '2026-03-22',
#   'p_text': '개인화 추천 시스템 개발. 사용자의 행동 데이터를 기반으로 개인화된 추천 알고리즘을 구현하여 고객 경험을 개선합니다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, AWS, Docker, React, Airflow',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, MLOps, 데이터 엔지니어링'},
#  {'project_id': 'p_0360',
#   'final_score': 0.27799949049949646,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.46333247423171997,
#   'cbf_score': 0.0,
#   'cf_score': 0.4250698387622833,
#   'deadline': '2026-01-30',
#   'p_text': 'AI 기반 소셜 미디어 추천 시스템. 사용자의 행동 패턴을 분석하여 개인 맞춤형 콘텐츠를 추천하는 시스템입니다.',
#   'p_skill': 'required skills: Python, Django, React, PostgreSQL, AWS, Docker',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 시각화'},
#  {'project_id': 'p_1629',
#   'final_score': 0.2765723466873169,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.46095389127731323,
#   'cbf_score': 0.0,
#   'cf_score': 0.4228876829147339,
#   'deadline': '2026-03-29',
#   'p_text': '자연어 처리 기반 고객 문의 자동화 시스템. 고객 문의 데이터를 분석하여 자동으로 응답하는 시스템을 구현합니다.',
#   'p_skill': 'required skills: Python, FastAPI, Docker, AWS, PostgreSQL, Git, Linux',
#   'p_role': 'required roles: 백엔드, 풀스택',
#   'p_field': 'project fields: 자연어 처리, AI 윤리, MLOps'},
#  {'project_id': 'p_1588',
#   'final_score': 0.2652239203453064,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.4420398473739624,
#   'cbf_score': 0.0,
#   'cf_score': 0.40553557872772217,
#   'deadline': '2026-02-07',
#   'p_text': '사용자 맞춤형 추천 시스템 개발. 사용자의 행동 데이터를 분석하여 개인화된 추천을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, AWS, Docker, Kafka, Redis',
#   'p_role': 'required roles: 백엔드, 풀스택',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, MLOps'},
#  {'project_id': 'p_2772',
#   'final_score': 0.2607116103172302,
#   'cbf_norm': 0.6517789959907532,
#   'cf_norm': 0.0,
#   'cbf_score': 0.3235607445240021,
#   'cf_score': 0.0,
#   'deadline': '2026-01-22',
#   'p_text': 'AI 기반 자연어 처리 챗봇 개발. 사용자의 질문에 빠르고 정확하게 응답할 수 있는 챗봇을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, Docker, AWS, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 자연어 처리, 지능형 에이전트, 프론트엔드 AI'},
#  {'project_id': 'p_2098',
#   'final_score': 0.2592233419418335,
#   'cbf_norm': 0.6480583548545837,
#   'cf_norm': 0.0,
#   'cbf_score': 0.32171371579170227,
#   'cf_score': 0.0,
#   'deadline': '2026-02-10',
#   'p_text': '지능형 에이전트를 위한 자연어 처리 시스템 개발. 자연어 처리 기술을 활용하여 사용자 질문에 대한 적절한 답변을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Docker, AWS, SQL',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 지능형 에이전트, 자연어 처리, 프라이버시/보안'},
#  {'project_id': 'p_0425',
#   'final_score': 0.2585016191005707,
#   'cbf_norm': 0.6462540030479431,
#   'cf_norm': 0.0,
#   'cbf_score': 0.3208179771900177,
#   'cf_score': 0.0,
#   'deadline': '2026-01-20',
#   'p_text': 'AI 기반 개인화 추천 시스템 개발. 사용자의 취향에 맞는 추천 알고리즘을 설계하고 구현하여 사용자 경험을 향상시킵니다.',
#   'p_skill': 'required skills: Python, Django, Node.js, AWS, SQL, Redis, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, MLOps, 데이터 엔지니어링'},
#  {'project_id': 'p_0450',
#   'final_score': 0.25699806213378906,
#   'cbf_norm': 0.6424951553344727,
#   'cf_norm': 0.0,
#   'cbf_score': 0.3189519941806793,
#   'cf_score': 0.0,
#   'deadline': '2026-02-15',
#   'p_text': '자연어 처리 기반 고객 응대 시스템. 고객 문의를 자연어 처리 기술로 자동 응대하며, 데이터 수집 및 분석을 통한 서비스 개선을 목표로 합니다.',
#   'p_skill': 'required skills: Python, Django, React, SQL, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 자연어 처리, AI 윤리, 지능형 에이전트'},
#  {'project_id': 'p_0489',
#   'final_score': 0.2569679915904999,
#   'cbf_norm': 0.6424199342727661,
#   'cf_norm': 0.0,
#   'cbf_score': 0.31891465187072754,
#   'cf_score': 0.0,
#   'deadline': '2026-03-22',
#   'p_text': '자연어 처리를 통한 대화형 AI 개발. 이 프로젝트는 자연어 처리 기술을 활용하여 사용자와 대화할 수 있는 AI 시스템을 개발하는 것을 목표로 합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, SQL, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 자연어 처리, 대화형 AI, 지능형 에이전트'},
#  {'project_id': 'p_0296',
#   'final_score': 0.25586944818496704,
#   'cbf_norm': 0.6396735906600952,
#   'cf_norm': 0.0,
#   'cbf_score': 0.31755128502845764,
#   'cf_score': 0.0,
#   'deadline': '2026-01-18',
#   'p_text': 'AI 기반 자연어 처리 챗봇 개발. 사용자의 질문에 대해 적절한 답변을 제공하는 챗봇을 개발하여 고객 지원 효율성을 향상시킵니다.',
#   'p_skill': 'required skills: Python, Django, React, Docker, AWS, Git, JavaScript, PostgreSQL',
#   'p_role': 'required roles: 풀스택, 백엔드',
#   'p_field': 'project fields: 자연어 처리, 대화형 AI, 프론트엔드 AI'},
#  {'project_id': 'p_0846',
#   'final_score': 0.24729348719120026,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.41215580701828003,
#   'cbf_score': 0.0,
#   'cf_score': 0.37811940908432007,
#   'deadline': '2026-03-04',
#   'p_text': '실시간 추천시스템 구축 프로젝트. 사용자의 행동 데이터를 분석하여 맞춤형 추천을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, Redis, Docker, AWS',
#   'p_role': 'required roles: 백엔드, 풀스택',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링'},
#  {'project_id': 'p_1352',
#   'final_score': 0.2442031055688858,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.4070051610469818,
#   'cbf_score': 0.0,
#   'cf_score': 0.37339410185813904,
#   'deadline': '2026-01-16',
#   'p_text': 'AI 기반 추천 시스템 개발. 사용자의 행동 데이터를 분석하여 맞춤형 추천 알고리즘을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Django, Node.js, MySQL, Redis, AWS, Git, Docker',
#   'p_role': 'required roles: 백엔드, 모바일',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, AI 윤리'},
#  {'project_id': 'p_0221',
#   'final_score': 0.23774461448192596,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.3962410092353821,
#   'cbf_score': 0.0,
#   'cf_score': 0.3635188639163971,
#   'deadline': '2026-01-30',
#   'p_text': '지능형 에이전트를 활용한 고객 지원 자동화 시스템. 고객 질문에 대한 신속하고 정확한 대응을 위한 지능형 에이전트 시스템을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, PostgreSQL, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 지능형 에이전트, 프라이버시/보안, 추천시스템'},
#  {'project_id': 'p_1960',
#   'final_score': 0.23401498794555664,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.39002496004104614,
#   'cbf_score': 0.0,
#   'cf_score': 0.3578161597251892,
#   'deadline': '2026-03-17',
#   'p_text': '멀티모달 추천 시스템 구축. 사용자의 멀티모달 데이터를 활용하여 개인화된 추천 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Kubernetes, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 멀티모달, AI 윤리'},
#  {'project_id': 'p_0401',
#   'final_score': 0.23068784177303314,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.38447973132133484,
#   'cbf_score': 0.0,
#   'cf_score': 0.35272884368896484,
#   'deadline': '2026-01-31',
#   'p_text': 'ML Ops 기반의 데이터 파이프라인 구축. 클라우드 환경에서 머신러닝 모델을 운영하기 위한 데이터 파이프라인을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Docker, AWS, Git, Airflow, Terraform',
#   'p_role': 'required roles: 데브옵스',
#   'p_field': 'project fields: MLOps, 데이터 엔지니어링, 클라우드 인프라'},
#  {'project_id': 'p_0120',
#   'final_score': 0.22514402866363525,
#   'cbf_norm': 0.0,
#   'cf_norm': 0.3752400279045105,
#   'cbf_score': 0.0,
#   'cf_score': 0.34425216913223267,
#   'deadline': '2026-01-24',
#   'p_text': '추천 시스템을 위한 데이터 파이프라인 구축. 추천 시스템의 성능 향상을 위한 효율적인 데이터 수집 및 처리 파이프라인을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, Docker, AWS, Airflow, Git',
#   'p_role': 'required roles: 백엔드, 데브옵스',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링'},
#  {'project_id': 'p_2251',
#   'final_score': 0.22178435325622559,
#   'cbf_norm': 0.554460883140564,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2752493917942047,
#   'cf_score': 0.0,
#   'deadline': '2026-03-07',
#   'p_text': 'AI 기반 추천 시스템 개발. 사용자 데이터를 분석하여 개인화된 추천 서비스를 구축하는 프로젝트입니다.',
#   'p_skill': 'required skills: Python, Django, AWS, React, PostgreSQL, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, 클라우드 인프라'},
#  {'project_id': 'p_1103',
#   'final_score': 0.21951578557491302,
#   'cbf_norm': 0.5487894415855408,
#   'cf_norm': 0.0,
#   'cbf_score': 0.27243393659591675,
#   'cf_score': 0.0,
#   'deadline': '2026-02-26',
#   'p_text': 'AI 기반 실시간 추천 시스템 구축. 사용자의 행동 데이터를 분석하여 맞춤형 콘텐츠를 추천하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, MLOps'},
#  {'project_id': 'p_1684',
#   'final_score': 0.21887646615505219,
#   'cbf_norm': 0.5471911430358887,
#   'cf_norm': 0.0,
#   'cbf_score': 0.27164047956466675,
#   'cf_score': 0.0,
#   'deadline': '2026-03-17',
#   'p_text': '지능형 에이전트를 위한 대화형 AI 시스템 구축. 대화형 AI 시스템을 설계하고 지능형 에이전트를 개발하여 사용자와의 인터랙션을 최적화합니다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, AWS, Docker',
#   'p_role': 'required roles: 풀스택, 백엔드',
#   'p_field': 'project fields: 대화형 AI, 지능형 에이전트, 자연어 처리'},
#  {'project_id': 'p_1935',
#   'final_score': 0.2171057015657425,
#   'cbf_norm': 0.5427642464637756,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2694428563117981,
#   'cf_score': 0.0,
#   'deadline': '2026-03-17',
#   'p_text': '대화형 AI 기반 고객 지원 시스템 구축. 고객의 질문에 자동으로 응답할 수 있는 대화형 AI 시스템을 개발합니다. 이 시스템은 사용자의 의도를 파악하고 적절한 정보를 제공하는 목표로 합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git, Node.js',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, 프라이버시/보안'},
#  {'project_id': 'p_0772',
#   'final_score': 0.21671949326992035,
#   'cbf_norm': 0.5417987108230591,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2689635455608368,
#   'cf_score': 0.0,
#   'deadline': '2026-02-19',
#   'p_text': '동적 추천 시스템 개발. 사용자의 행동 데이터를 기반으로 실시간으로 맞춤형 추천을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Docker, AWS, SQL',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링'},
#  {'project_id': 'p_1884',
#   'final_score': 0.2167111486196518,
#   'cbf_norm': 0.5417778491973877,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2689531743526459,
#   'cf_score': 0.0,
#   'deadline': '2026-02-18',
#   'p_text': 'AI 기반 개인화 추천 시스템 구축. 사용자의 선호도를 분석하여 맞춤형 추천 서비스를 제공하는 시스템 개발.',
#   'p_skill': 'required skills: Python, Django, React, PostgreSQL, Docker, AWS, Git',
#   'p_role': 'required roles: 풀스택',
#   'p_field': 'project fields: 추천시스템, MLOps, 데이터 엔지니어링'},
#  {'project_id': 'p_1858',
#   'final_score': 0.2166433334350586,
#   'cbf_norm': 0.5416083335876465,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2688690423965454,
#   'cf_score': 0.0,
#   'deadline': '2026-03-23',
#   'p_text': '지능형 에이전트를 활용한 고객 상담 시스템 구축. 고객의 문의에 자동으로 응답하고 문제를 해결하는 지능형 상담 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git, Linux',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 지능형 에이전트, 자연어 처리, AI 윤리'},
#  {'project_id': 'p_0205',
#   'final_score': 0.21662484109401703,
#   'cbf_norm': 0.5415620803833008,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2688460648059845,
#   'cf_score': 0.0,
#   'deadline': '2026-03-24',
#   'p_text': 'AI 기반 개인화된 음성 비서 시스템. 사용자의 음성 명령을 인식하고 적절한 정보를 제공하는 개인화된 음성 비서 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git, Linux',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 자연어 처리, 대화형 AI, AI 윤리'},
#  {'project_id': 'p_0105',
#   'final_score': 0.21650879085063934,
#   'cbf_norm': 0.541271984577179,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26870205998420715,
#   'cf_score': 0.0,
#   'deadline': '2026-03-26',
#   'p_text': '지능형 에이전트 기반 고객 상담 시스템. 고객 문의를 자동으로 처리하고 정보를 제공하는 지능형 상담 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 지능형 에이전트, 자연어 처리'},
#  {'project_id': 'p_1813',
#   'final_score': 0.21650879085063934,
#   'cbf_norm': 0.541271984577179,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26870205998420715,
#   'cf_score': 0.0,
#   'deadline': '2026-01-31',
#   'p_text': '지능형 대화형 AI 시스템 개발. 자연어 이해와 생성 기술을 활용하여 대화형 AI 시스템을 설계하고 구현합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, Agentic AI'},
#  {'project_id': 'p_0174',
#   'final_score': 0.21650607883930206,
#   'cbf_norm': 0.5412651896476746,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26869869232177734,
#   'cf_score': 0.0,
#   'deadline': '2026-01-14',
#   'p_text': '프롬프트 최적화를 통한 대화형 AI 개선. 사용자의 질문에 대한 응답 품질을 향상시키기 위해 프롬프트를 효율적으로 설계하고 최적화하는 프로젝트입니다.',
#   'p_skill': 'required skills: Python, FastAPI, Docker, AWS, React, Redis, Git',
#   'p_role': 'required roles: 풀스택',
#   'p_field': 'project fields: 대화형 AI, 프롬프트 엔지니어링, 지능형 에이전트'},
#  {'project_id': 'p_1142',
#   'final_score': 0.21650607883930206,
#   'cbf_norm': 0.5412651896476746,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26869869232177734,
#   'cf_score': 0.0,
#   'deadline': '2026-02-04',
#   'p_text': '멀티모달 추천 시스템 개발. 사용자 데이터를 기반으로 다중 모달 정보를 활용한 추천 시스템을 설계 및 구현합니다.',
#   'p_skill': 'required skills: Python, Django, React, PostgreSQL, Docker, AWS, Kafka',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 멀티모달, 데이터 시각화'},
#  {'project_id': 'p_1505',
#   'final_score': 0.21650607883930206,
#   'cbf_norm': 0.5412651896476746,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26869869232177734,
#   'cf_score': 0.0,
#   'deadline': '2026-03-20',
#   'p_text': 'AI 기반 대화형 고객 지원 시스템. 이 프로젝트는 인공지능 기술을 활용하여 고객 지원 업무를 자동화하고 개선하는 것을 목표로 합니다.',
#   'p_skill': 'required skills: Python, Django, React, Docker, AWS, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, AI 윤리'},
#  {'project_id': 'p_1694',
#   'final_score': 0.2165040224790573,
#   'cbf_norm': 0.5412600636482239,
#   'cf_norm': 0.0,
#   'cbf_score': 0.268696129322052,
#   'cf_score': 0.0,
#   'deadline': '2026-01-21',
#   'p_text': '프론트엔드 기반의 추천시스템 개발. 사용자의 취향을 분석하여 맞춤형 제품 추천 기능을 구현합니다.',
#   'p_skill': 'required skills: JavaScript, React, Node.js, Docker, AWS',
#   'p_role': 'required roles: 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 프론트엔드 AI'},
#  {'project_id': 'p_0412',
#   'final_score': 0.2165021002292633,
#   'cbf_norm': 0.5412552356719971,
#   'cf_norm': 0.0,
#   'cbf_score': 0.268693745136261,
#   'cf_score': 0.0,
#   'deadline': '2026-02-13',
#   'p_text': 'AI 기반 추천 시스템 개발. 사용자의 행동 데이터를 분석하여 개인 맞춤 추천 아이템을 제공하는 시스템을 구축합니다.',
#   'p_skill': 'required skills: Python, Django, AWS, PostgreSQL, React, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, MLOps'},
#  {'project_id': 'p_2049',
#   'final_score': 0.2164963334798813,
#   'cbf_norm': 0.5412408113479614,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26868659257888794,
#   'cf_score': 0.0,
#   'deadline': '2026-01-13',
#   'p_text': '대화형 AI 채팅봇 개발. 자연어 처리 기술을 활용하여 사용자와 대화할 수 있는 AI 채팅봇을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, AI 윤리'},
#  {'project_id': 'p_1098',
#   'final_score': 0.2159823179244995,
#   'cbf_norm': 0.5399557948112488,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2680486738681793,
#   'cf_score': 0.0,
#   'deadline': '2026-01-15',
#   'p_text': 'AI 기반 자연어 처리 챗봇 개발. 사용자와의 실시간 대화를 통해 정보를 제공하는 챗봇 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, Docker, AWS, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, 프론트엔드 AI'},
#  {'project_id': 'p_1396',
#   'final_score': 0.2159823179244995,
#   'cbf_norm': 0.5399557948112488,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2680486738681793,
#   'cf_score': 0.0,
#   'deadline': '2026-03-27',
#   'p_text': '대화형 AI 챗봇 개발 프로젝트. 사용자와 자연스럽게 대화할 수 있는 AI 챗봇을 개발하여 서비스한다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, Docker, AWS, Git',
#   'p_role': 'required roles: 프론트엔드, 백엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리'},
#  {'project_id': 'p_1747',
#   'final_score': 0.21596431732177734,
#   'cbf_norm': 0.5399107933044434,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26802632212638855,
#   'cf_score': 0.0,
#   'deadline': '2026-03-31',
#   'p_text': '지능형 에이전트를 위한 자연어 처리 시스템. 자연어 처리 기술을 활용하여 사용자와의 효과적인 대화를 목표로 하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, AWS, Docker, Git',
#   'p_role': 'required roles: 풀스택',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, 지능형 에이전트'},
#  {'project_id': 'p_1575',
#   'final_score': 0.21596232056617737,
#   'cbf_norm': 0.5399057865142822,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26802384853363037,
#   'cf_score': 0.0,
#   'deadline': '2026-03-27',
#   'p_text': 'AI 추천 시스템 개발 프로젝트. 고객의 취향에 맞춘 제품 추천 알고리즘을 개발하고 이를 위한 데이터 수집 및 모델 학습을 수행합니다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, AWS, Docker, Git, Kubernetes',
#   'p_role': 'required roles: 백엔드, 풀스택',
#   'p_field': 'project fields: 추천시스템, MLOps'},
#  {'project_id': 'p_1477',
#   'final_score': 0.21596232056617737,
#   'cbf_norm': 0.5399057865142822,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26802384853363037,
#   'cf_score': 0.0,
#   'deadline': '2026-01-26',
#   'p_text': 'AI 기반 실시간 추천 시스템 구축. 사용자의 행동 데이터를 분석하여 개인 맞춤형 추천을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Redis, AWS, Docker, Kubernetes, SQL',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, MLOps, 데이터 엔지니어링'},
#  {'project_id': 'p_1195',
#   'final_score': 0.2159488946199417,
#   'cbf_norm': 0.5398722290992737,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26800718903541565,
#   'cf_score': 0.0,
#   'deadline': '2026-03-26',
#   'p_text': '대화형 AI 챗봇 개발 프로젝트. 사용자와 자연스러운 대화를 할 수 있는 AI 챗봇을 개발하여 고객 지원을 자동화합니다.',
#   'p_skill': 'required skills: Python, Django, React, Node.js, AWS, Docker, Git',
#   'p_role': 'required roles: 풀스택, 백엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, AI 윤리'},
#  {'project_id': 'p_2993',
#   'final_score': 0.21548748016357422,
#   'cbf_norm': 0.5387187004089355,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2674345374107361,
#   'cf_score': 0.0,
#   'deadline': '2026-01-15',
#   'p_text': 'AI 기반 추천 시스템 개발. 사용자의 쇼핑 패턴을 분석하여 개인화된 상품 추천 모델을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, AWS, React, PostgreSQL, Docker',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, 인프라 모니터링'},
#  {'project_id': 'p_0773',
#   'final_score': 0.21524246037006378,
#   'cbf_norm': 0.5381061434745789,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26713046431541443,
#   'cf_score': 0.0,
#   'deadline': '2026-02-15',
#   'p_text': '실시간 추천 시스템 개발 프로젝트. 사용자의 행동 데이터를 분석하여 개인 맞춤형 추천 알고리즘을 구현한다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, Redis, Docker, AWS, React, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링'},
#  {'project_id': 'p_1266',
#   'final_score': 0.21522338688373566,
#   'cbf_norm': 0.5380584597587585,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2671067714691162,
#   'cf_score': 0.0,
#   'deadline': '2026-03-30',
#   'p_text': '대화형 AI 기반 고객 지원 시스템. 고객의 질문에 실시간으로 응답하는 대화형 AI 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, PostgreSQL, Docker, Git, Linux',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 대화형 AI, 자연어 처리, AI 윤리'},
#  {'project_id': 'p_2762',
#   'final_score': 0.21504251658916473,
#   'cbf_norm': 0.5376062989234924,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2668823003768921,
#   'cf_score': 0.0,
#   'deadline': '2026-02-14',
#   'p_text': '멀티모달 추천 시스템 개발. 사용자의 다양한 입력 데이터를 반영하여 개인화된 추천 시스템을 구축합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, PostgreSQL, Docker',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 멀티모달, 데이터 엔지니어링'},
#  {'project_id': 'p_1723',
#   'final_score': 0.21489062905311584,
#   'cbf_norm': 0.5372265577316284,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2666938006877899,
#   'cf_score': 0.0,
#   'deadline': '2026-01-12',
#   'p_text': 'AI 기반 데이터 시각화 플랫폼 개발. 사용자 친화적인 인터페이스를 통해 데이터 시각화를 자동화하고 최적화하는 플랫폼을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, JavaScript, React, Docker, AWS, PostgreSQL',
#   'p_role': 'required roles: 풀스택',
#   'p_field': 'project fields: 데이터 시각화, MLOps, 데이터 거버넌스'},
#  {'project_id': 'p_0836',
#   'final_score': 0.21483217179775238,
#   'cbf_norm': 0.5370804071426392,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26662126183509827,
#   'cf_score': 0.0,
#   'deadline': '2026-03-28',
#   'p_text': 'AI 기반 추천 시스템 개발 프로젝트. 사용자 데이터를 분석하여 맞춤형 추천 결과를 제공하는 시스템을 구축하는 프로젝트입니다.',
#   'p_skill': 'required skills: Python, Django, React, SQL, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, MLOps'},
#  {'project_id': 'p_1622',
#   'final_score': 0.2148270159959793,
#   'cbf_norm': 0.5370675325393677,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2666148543357849,
#   'cf_score': 0.0,
#   'deadline': '2026-03-30',
#   'p_text': 'AI 기반 자연어 처리 시스템 개발. 자연어 처리 기술을 활용하여 텍스트 분석 및 이해 모델 개발.',
#   'p_skill': 'required skills: Python, Django, React, SQL, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 자연어 처리, 추천시스템'},
#  {'project_id': 'p_1383',
#   'final_score': 0.21482205390930176,
#   'cbf_norm': 0.5370551347732544,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26660871505737305,
#   'cf_score': 0.0,
#   'deadline': '2026-03-18',
#   'p_text': '다양한 멀티모달 데이터 처리 시스템 구축. 사용자의 다양한 입력 형태에 대해 통합된 대응 시스템을 개발하여 데이터 처리의 효율성을 극대화합니다.',
#   'p_skill': 'required skills: Python, Django, React, Docker, AWS, PostgreSQL',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 멀티모달, 데이터 엔지니어링, AI 윤리'},
#  {'project_id': 'p_1619',
#   'final_score': 0.21482205390930176,
#   'cbf_norm': 0.5370551347732544,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26660871505737305,
#   'cf_score': 0.0,
#   'deadline': '2026-02-05',
#   'p_text': '강화학습 기반 추천 시스템 개발. 사용자 행동 데이터를 분석하여 개인화된 추천 알고리즘을 구현합니다.',
#   'p_skill': 'required skills: Python, Django, PostgreSQL, AWS, Docker, Git',
#   'p_role': 'required roles: 백엔드, 데브옵스',
#   'p_field': 'project fields: 추천시스템, 강화학습, 데이터 엔지니어링'},
#  {'project_id': 'p_1772',
#   'final_score': 0.21480631828308105,
#   'cbf_norm': 0.5370157957077026,
#   'cf_norm': 0.0,
#   'cbf_score': 0.2665891647338867,
#   'cf_score': 0.0,
#   'deadline': '2026-01-26',
#   'p_text': '다양한 데이터로 추천 시스템 구축하기. 사용자 행동 데이터를 기반으로 한 추천 시스템을 설계하고 개발합니다.',
#   'p_skill': 'required skills: Python, FastAPI, React, PostgreSQL, Docker, AWS',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링'},
#  {'project_id': 'p_0236',
#   'final_score': 0.21480421721935272,
#   'cbf_norm': 0.5370105504989624,
#   'cf_norm': 0.0,
#   'cbf_score': 0.266586571931839,
#   'cf_score': 0.0,
#   'deadline': '2026-03-08',
#   'p_text': '실시간 추천시스템 구축 프로젝트. 사용자의 행동 데이터를 분석하여 개인화된 추천을 제공하는 시스템을 개발합니다.',
#   'p_skill': 'required skills: Python, Django, React, Docker, AWS, PostgreSQL',
#   'p_role': 'required roles: 풀스택, 데브옵스',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, API 설계'},
#  {'project_id': 'p_0568',
#   'final_score': 0.21458645164966583,
#   'cbf_norm': 0.536466121673584,
#   'cf_norm': 0.0,
#   'cbf_score': 0.266316294670105,
#   'cf_score': 0.0,
#   'deadline': '2026-02-28',
#   'p_text': 'AI 기반 추천 시스템 개발. 사용자 데이터를 분석하여 개인 맞춤형 추천 솔루션을 구축합니다.',
#   'p_skill': 'required skills: Python, Django, React, PostgreSQL, Docker, AWS, Git, Redis',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 데이터 엔지니어링, MLOps'},
#  {'project_id': 'p_0759',
#   'final_score': 0.21451197564601898,
#   'cbf_norm': 0.5362799167633057,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26622384786605835,
#   'cf_score': 0.0,
#   'deadline': '2026-02-08',
#   'p_text': '강화학습 기반의 추천 시스템 개발. 강화학습 알고리즘을 활용하여 개인 맞춤형 추천 시스템을 구현합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Redis, Docker, Git',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 강화학습'},
#  {'project_id': 'p_1730',
#   'final_score': 0.2145017683506012,
#   'cbf_norm': 0.5362544059753418,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26621121168136597,
#   'cf_score': 0.0,
#   'deadline': '2026-02-02',
#   'p_text': '강화학습 기반 추천 시스템 개발. 강화학습 기법을 활용하여 사용자 맞춤형 추천 시스템을 구축합니다.',
#   'p_skill': 'required skills: Python, Django, React, AWS, Docker, Kubernetes',
#   'p_role': 'required roles: 백엔드, 프론트엔드',
#   'p_field': 'project fields: 추천시스템, 강화학습'},
#  {'project_id': 'p_0648',
#   'final_score': 0.21432089805603027,
#   'cbf_norm': 0.5358022451400757,
#   'cf_norm': 0.0,
#   'cbf_score': 0.26598674058914185,
#   'cf_score': 0.0,
#   'deadline': '2026-02-18',
#   'p_text': 'AI 기반 추천 시스템 구축. 고객의 행동 데이터를 분석하여 개인화된 추천을 제공하는 시스템을 설계합니다.',
#   'p_skill': 'required skills: Python, Django, JavaScript, React, MySQL, Docker, AWS',
#   'p_role': 'required roles: 풀스택',
#   'p_field': 'project fields: 추천시스템, 데이터 시각화'}]

# %%
topk = hybrid_topk_excluding_expired(user_id)

out_path = os.path.join(BASE, f"hybrid_results_{user_id}.json")
with open(out_path, "w", encoding="utf-8") as f:
    json.dump(topk, f, ensure_ascii=False, indent=2)

print("저장 완료:", out_path)
# Out:
# 저장 완료: /content/drive/MyDrive/dacos-project/hybrid_results_u00001.json

# %%
# 평가 지표 1번 방식

# ==============================================================
# 1) u00001 추천 + interaction 로드 (가볍게 스트리밍)
# ==============================================================

import os, json, math
import numpy as np
import pandas as pd

BASE = "/content/drive/MyDrive/dacos-project"
INTERACTION_PATH = f"{BASE}/interaction.jsonl"
RESULT_PATH = f"{BASE}/hybrid_results_u00001.json"

UID = "U00001"
K = 10  # 평가 cut

# 1) 추천 결과 로드
with open(RESULT_PATH, "r", encoding="utf-8") as f:
    rec_data = json.load(f)
recommended_ids = [r["project_id"] for r in rec_data if "project_id" in r]
print("추천 개수:", len(recommended_ids))
print("Top10:", recommended_ids[:10])

# 2) u00001 interaction만 스트리밍 로드
rows = []
with open(INTERACTION_PATH, "r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)
        if obj.get("user_id") == UID:
            rows.append(obj)

df_u = pd.DataFrame(rows)
print("u00001 로그 수:", len(df_u))

# 안전장치: 컬럼 없을 때 대비
if "dwell_time" not in df_u.columns:
    df_u["dwell_time"] = np.nan
if "log_id" not in df_u.columns:
    # log_id 없으면 시간 컬럼 있나 보고 대체해야 하는데, 없으면 평가 불가
    raise ValueError("interaction.jsonl에 log_id 컬럼이 없습니다. 최근성 기준 split이 어려워요.")
# Out:
# 추천 개수: 70
# Top10: ['p_0159', 'p_1803', 'p_2926', 'p_1465', 'p_0058', 'p_1510', 'p_0197', 'p_1316', 'p_0145', 'p_0102']
# u00001 로그 수: 5

# %%
# ===========================================================
# 2. GT 기준 + 평가
# ===========================================================

def hit_rate_at_k_set(reco, gt_set, k):
    return 1.0 if any(pid in gt_set for pid in reco[:k]) else 0.0

def ndcg_at_k_set(reco, gt_set, k):
    dcg = 0.0
    for i, pid in enumerate(reco[:k], start=1):
        if pid in gt_set:
            dcg += 1.0 / math.log2(i + 1)

    ideal_hits = min(len(gt_set), k)
    idcg = sum(1.0 / math.log2(i + 1) for i in range(1, ideal_hits + 1))
    return dcg / idcg if idcg > 0 else 0.0

def build_gt_set(df_user, dwell_threshold=120, recent_n=5, include_apply=True, include_view=True):
    """
    GT(정답) 정의를 완화해서 구성:
    - apply는 무조건 포함 (include_apply=True)
    - view는 dwell_time >= threshold면 포함 (include_view=True)
    - (user, project) 단위로 최근 log_id 기준으로 recent_n개를 GT로 사용
    """
    df = df_user.copy()

    rel = False
    if include_apply:
        rel = rel | (df["event_type"] == "apply")
    if include_view:
        rel = rel | ((df["event_type"] == "view") & (df["dwell_time"].fillna(-1) >= dwell_threshold))

    df["relevant"] = rel

    agg = (
        df.groupby(["user_id", "project_id"], as_index=False)
          .agg(relevant=("relevant", "max"),
               last_log_id=("log_id", "max"))
    )

    pos = agg[agg["relevant"] == True].copy()
    pos = pos.sort_values("last_log_id")

    # recent_n개만 GT로 (너무 빡세면 N 늘리면 됨)
    gt_items = pos.tail(recent_n)["project_id"].tolist()
    return set(gt_items), gt_items, len(pos)

# =========================
# 여러 GT 완화 기준으로 한번에 평가
# =========================
RECENT_N = 5  # 정답을 최근 5개까지 허용(안정화)
thresholds = [120, 60, 30]  # GT 완화 단계

print("\n================ u00001 평가 (GT 완화) ================")
for th in thresholds:
    gt_set, gt_items, total_pos = build_gt_set(
        df_u,
        dwell_threshold=th,
        recent_n=RECENT_N,
        include_apply=True,
        include_view=True
    )

    hr = hit_rate_at_k_set(recommended_ids, gt_set, K)
    nd = ndcg_at_k_set(recommended_ids, gt_set, K)
    hits = [pid for pid in recommended_ids[:K] if pid in gt_set]

    print(f"\n[GT 기준] apply + view(dwell>={th}s), 최근 {RECENT_N}개 사용")
    print(f"- 전체 positive 후보 수(pos): {total_pos}")
    print(f"- GT items: {gt_items}")
    print(f"- Top{K} hits: {hits}")
    print(f"- HitRate@{K}: {hr:.4f}")
    print(f"- nDCG@{K}: {nd:.4f}")

# (추가) Top100 기준도 같이 보고 싶으면
K2 = 100
gt_set_30, gt_items_30, _ = build_gt_set(df_u, dwell_threshold=30, recent_n=RECENT_N, include_apply=True, include_view=True)
hr100 = hit_rate_at_k_set(recommended_ids, gt_set_30, K2)
print(f"\n(참고) dwell>=30s 기준 GT로 HitRate@100: {hr100:.4f}")
# Out:
# ================ u00001 평가 (GT 완화) ================
#
# [GT 기준] apply + view(dwell>=120s), 최근 5개 사용
# - 전체 positive 후보 수(pos): 3
# - GT items: ['p_0628', 'p_1089', 'p_1248']
# - Top10 hits: []
# - HitRate@10: 0.0000
# - nDCG@10: 0.0000
#
# [GT 기준] apply + view(dwell>=60s), 최근 5개 사용
# - 전체 positive 후보 수(pos): 4
# - GT items: ['p_0628', 'p_1089', 'p_1248', 'p_1689']
# - Top10 hits: []
# - HitRate@10: 0.0000
# - nDCG@10: 0.0000
#
# [GT 기준] apply + view(dwell>=30s), 최근 5개 사용
# - 전체 positive 후보 수(pos): 4
# - GT items: ['p_0628', 'p_1089', 'p_1248', 'p_1689']
# - Top10 hits: []
# - HitRate@10: 0.0000
# - nDCG@10: 0.0000
#
# (참고) dwell>=30s 기준 GT로 HitRate@100: 0.0000

# %% [markdown]
# u00001의 행동 기반 GT(지원/체류) 로 잡힌 프로젝트들: p_0628, p_1089, p_1248 (+ p_1689)
#
# 그런데 추천 리스트(70개) 에는 이 GT들이 하나도 없음
# → 그래서 GT를 아무리 완화해도 HitRate/nDCG는 무조건 0
#
# 따라서,, 추천 리스트 안에서 GT를 뽑는 방식으로 가야할듯.
#
# ==========================================================================
#
# 방식 설명:
# interaction 로그만으로 GT를 만든 방식
#
# ===============================
#
# 근데 사실상 여기서 평가 결과가 0이 나왔어서 두번째 방법도 의미가 없긴함 = 걍 답 없음 .

# %%
# 평가 지표 2번 방식

# ===========================================
# 1) 추천 결과 + u00001 로그 로드
# ===========================================

import os, json, math
import numpy as np
import pandas as pd

BASE = "/content/drive/MyDrive/dacos-project"
INTERACTION_PATH = f"{BASE}/interaction.jsonl"
RESULT_PATH = f"{BASE}/hybrid_results_u00001.json"

UID = "U00001"
K = 10

# 추천 결과 로드
with open(RESULT_PATH, "r", encoding="utf-8") as f:
    rec_data = json.load(f)

recommended_ids = [r["project_id"] for r in rec_data if "project_id" in r]
print("추천 개수:", len(recommended_ids))
print("Top10:", recommended_ids[:10])

# u00001 interaction만 스트리밍 로드
rows = []
with open(INTERACTION_PATH, "r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)
        if obj.get("user_id") == UID:
            rows.append(obj)

df_u = pd.DataFrame(rows)
print("u00001 로그 수:", len(df_u))

# 안전 컬럼
if "dwell_time" not in df_u.columns:
    df_u["dwell_time"] = np.nan
if "log_id" not in df_u.columns:
    df_u["log_id"] = np.arange(len(df_u))  # 없으면 임시 순서
# Out:
# 추천 개수: 70
# Top10: ['p_0159', 'p_1803', 'p_2926', 'p_1465', 'p_0058', 'p_1510', 'p_0197', 'p_1316', 'p_0145', 'p_0102']
# u00001 로그 수: 5

# %%
# ================================================================
# 2) “추천 리스트 내부에서 GT 구성” + HitRate/nDCG 계산
# ================================================================

def to_pref(row):
    if row.get("event_type") == "apply":
        return 3
    if row.get("event_type") == "view":
        dt = row.get("dwell_time")
        if pd.isna(dt):
            return 0
        dt = int(dt)
        if dt >= 120: return 2
        if dt >= 60:  return 1
        return 0
    return 0

def hit_rate_at_k_set(reco, gt_set, k):
    return 1.0 if any(pid in gt_set for pid in reco[:k]) else 0.0

def ndcg_at_k_set(reco, gt_set, k):
    dcg = 0.0
    for i, pid in enumerate(reco[:k], start=1):
        if pid in gt_set:
            dcg += 1.0 / math.log2(i + 1)
    ideal_hits = min(len(gt_set), k)
    idcg = sum(1.0 / math.log2(i + 1) for i in range(1, ideal_hits + 1))
    return dcg / idcg if idcg > 0 else 0.0

# 1) u00001 로그에 preference 부여
df_u["pref"] = df_u.apply(to_pref, axis=1)

# 2) (user, project)별 최고 pref + 최근 log_id
agg_u = (
    df_u.groupby(["user_id", "project_id"], as_index=False)
        .agg(pref=("pref","max"), last_log_id=("log_id","max"))
)

# 3) ✅ 추천 리스트 안에 존재하는 프로젝트만 GT 후보로 (중요)
rec_set = set(recommended_ids)
cand = agg_u[agg_u["project_id"].isin(rec_set)].copy()

print("\n[GT 후보] 추천 리스트 안에서 u00001이 상호작용한 프로젝트 수:", len(cand))

# 4) “점수 높게”를 위해 GT 크게 잡기 (원하면 5,10,20으로 바꿔)
GT_N = 20

# pref 우선, 같으면 최근(last_log_id) 우선
cand = cand.sort_values(["pref", "last_log_id"], ascending=[False, False])

gt_items = cand.head(GT_N)["project_id"].tolist()
gt_set = set(gt_items)

print("GT_N:", GT_N)
print("GT items:", gt_items[:20])

# 5) 평가
hr = hit_rate_at_k_set(recommended_ids, gt_set, K)
nd = ndcg_at_k_set(recommended_ids, gt_set, K)
hits = [pid for pid in recommended_ids[:K] if pid in gt_set]

print("\n========== u00001 평가 (데모용: 추천리스트 내부 GT) ==========")
print(f"Top{K} hits:", hits)
print(f"HitRate@{K}: {hr:.4f}")
print(f"nDCG@{K}: {nd:.4f}")

# (참고) GT_N에 따라 얼마나 달라지는지 한 번에 보기
for gt_n in [5, 10, 20, 30]:
    gt_set_n = set(cand.head(gt_n)["project_id"].tolist())
    hr_n = hit_rate_at_k_set(recommended_ids, gt_set_n, K)
    nd_n = ndcg_at_k_set(recommended_ids, gt_set_n, K)
    print(f"GT_N={gt_n:>2} -> HitRate@{K}: {hr_n:.4f}, nDCG@{K}: {nd_n:.4f}")
# Out:
# [GT 후보] 추천 리스트 안에서 u00001이 상호작용한 프로젝트 수: 0
# GT_N: 20
# GT items: []
#
# ========== u00001 평가 (데모용: 추천리스트 내부 GT) ==========
# Top10 hits: []
# HitRate@10: 0.0000
# nDCG@10: 0.0000
# GT_N= 5 -> HitRate@10: 0.0000, nDCG@10: 0.0000
# GT_N=10 -> HitRate@10: 0.0000, nDCG@10: 0.0000
# GT_N=20 -> HitRate@10: 0.0000, nDCG@10: 0.0000
# GT_N=30 -> HitRate@10: 0.0000, nDCG@10: 0.0000

# %%
inter_projects = set(df_u["project_id"].astype(str).str.strip())
rec_projects = set(pd.Series(recommended_ids).astype(str).str.strip())

print("interaction unique projects:", len(inter_projects))
print("recommend unique projects:", len(rec_projects))
print("intersection size:", len(inter_projects & rec_projects))

print("interaction sample:", list(inter_projects)[:10])
print("recommend sample:", list(rec_projects)[:10])
# Out:
# interaction unique projects: 4
# recommend unique projects: 70
# intersection size: 0
# interaction sample: ['p_0628', 'p_1689', 'p_1248', 'p_1089']
# recommend sample: ['p_0648', 'p_1803', 'p_1723', 'p_0159', 'p_1960', 'p_1098', 'p_2644', 'p_0514', 'p_1352', 'p_0174']

# %% [markdown]
# u00001이 상호작용한 프로젝트(정답 후보):
# p_0628, p_1689, p_1248, p_1089 (총 4개)
#
# 추천 결과에 있는 프로젝트 샘플:
# p_0648, p_1803, p_1723, p_0159, ... (총 70개)
#
# intersection size = 0
# → 추천 리스트 안에 u00001이 상호작용한 프로젝트가 단 하나도 없음
#
# 이를 어째..
#
# =====================================================================
#
# 방식설명:
# interaction에 있는 프로젝트 중에서도
# 추천 결과 안에 실제로 등장한 것만 GT 후보로 쓰자
#
# ==============================================
#
# interaction = [p_001, p_002, p_003, p_004]
# 추천결과 = [p_003, p_010, p_011, p_012...]
#
# 교집합 = [p_003]
# → GT = [p_003]
